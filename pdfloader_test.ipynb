# %%
import loan_screening_pdf_loader as ll

# %%
dfs = ll.table2df('C:/Users/user/downloads/test3.pdf')
dfs
# Out:
# [                                                 발급번호       Col1  \
#  0                                                           None
#  1                                                 주 소       None
#  2                                                 성 명       None
#  3                       ◇ 종합소득세 신고(결정·경정) 현황 (단위 : 원)       None
#  4                                                 구 분       None
#  5                                                None       None
#  6                                                수입금액       None
#  7                                                소득금액       None
#  8   * 종합과세 소득금액은 이월결손금을 공제하지 않은 금액임\n* 분리과세 : 종합소득...       None
#  9                                                 구 분  소 득 발 생 처
#  10                                               None    법인명(상호)
#  11                                               사업소득
#  12                                               근로소득
#  13                                               연금소득
# ...

# %%
len(dfs)
# Out:
# 1

# %%
df = dfs[0]

# %%
df
# Out:
#                                                  발급번호       Col1  \
# 0                                                           None
# 1                                                 주 소       None
# 2                                                 성 명       None
# 3                       ◇ 종합소득세 신고(결정·경정) 현황 (단위 : 원)       None
# 4                                                 구 분       None
# 5                                                None       None
# 6                                                수입금액       None
# 7                                                소득금액       None
# 8   * 종합과세 소득금액은 이월결손금을 공제하지 않은 금액임\n* 분리과세 : 종합소득...       None
# 9                                                 구 분  소 득 발 생 처
# 10                                               None    법인명(상호)
# 11                                               사업소득
# 12                                               근로소득
# 13                                               연금소득
# ...

# %%
import pandas as pd

# %%
df1 = df.iloc[5 : 9]

# %%
df1
# Out:
#                                                 발급번호  Col1  \
# 5                                               None  None
# 6                                               수입금액  None
# 7                                               소득금액  None
# 8  * 종합과세 소득금액은 이월결손금을 공제하지 않은 금액임\n* 분리과세 : 종합소득...  None
#
#   소 득 금 액 증 명(개정후)\n(2020 년 귀속)  Col3  Col4  Col5    Col6      Col7  Col8  \
# 5                            이자    배당  None  None      사업        근로  None
# 6                          4000  3000  None  None  100000  30000000  None
# 7                          4000  3000  None  None   70000  27000000  None
# 8                          None  None  None  None    None      None  None
#
#    Col9 Col10 Col11 Col12   처 리 기 간 Col14 Col15 Col16 Col17
# 5    연금  None  None    기타        합계  None  None  None  None
# 6     0  None  None     -  60000000  None        None
# 7     0  None  None     -  50000000  None        None  None
# 8  None  None  None  None      None  None  None  None  None

# %%
df2 = df.iloc[6 : 8]
df2
# Out:
#    발급번호  Col1 소 득 금 액 증 명(개정후)\n(2020 년 귀속)  Col3  Col4  Col5    Col6  \
# 6  수입금액  None                          4000  3000  None  None  100000
# 7  소득금액  None                          4000  3000  None  None   70000
#
#        Col7  Col8 Col9 Col10 Col11 Col12   처 리 기 간 Col14 Col15 Col16 Col17
# 6  30000000  None    0  None  None     -  60000000  None        None
# 7  27000000  None    0  None  None     -  50000000  None        None  None

# %%
df2['처 리 기 간']
# Out:
# 6    60000000
# 7    50000000
# Name: 처 리 기 간, dtype: object

# %%
income = ll.income('C:/Users/user/downloads/test3.pdf')
income
# Out:
# d:\chatbot_main\loan_screening_pdf_loader.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   income = income_[13]
# 50000000.0

# %%
type(income)
# Out:
# float

# %%
df3 = df.loc[7]

# %%
df3
# Out:
# 발급번호                                 소득금액
# Col1                                 None
# 소 득 금 액 증 명(개정후)\n(2020 년 귀속)        4000
# Col3                                 3000
# Col4                                 None
# Col5                                 None
# Col6                                70000
# Col7                             27000000
# Col8                                 None
# Col9                                    0
# Col10                                None
# Col11                                None
# Col12                                   -
# 처 리 기 간                          50000000
# Col14                                None
# Col15
# Col16                                None
# Col17                                None
# Name: 7, dtype: object

# %%
df3[13]
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_26068\3858090741.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df3[13]
# '50000000'
