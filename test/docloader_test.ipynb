# %%
from DocLoader import docload
# pages = docload('C:/Users/user/Downloads/가계대출상품설명서.pdf')
# pages

# %%
from DocLoader import extract_text
tables = extract_text('C:/Users/user/Downloads/가계대출상품설명서.pdf')
tables[0]
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 5천만원 초과   1억원 초과 Unnamed: 3
# 0       대출금액        NaN    5천만원 이하     NaN      NaN    10억원 초과
# 1        NaN        NaN        NaN  1억원 이하  10억원 이하        NaN
# 2       인지세액        NaN        비과세     7만원     15만원       35만원
# 3        NaN       고객부담          -   3만5천원    7만5천원     17만5천원
# 4        NaN       은행부담          -   3만5천원    7만5천원     17만5천원

# %%
tables[1]
# Out:
#                  상환기간 원금  Unnamed: 0       이자      상환금액     대출잔액
# 0             1년 1,810만원         NaN    500만원   2,310만원  8,910만원
# 1             2년 1,900만원         NaN    410만원   2,310만원  6,290만원
# 2             3년 1,995만원         NaN    315만원   2,310만원  4,295만원
# 3             4년 2,095만원         NaN    215만원   2,310만원  2,200만원
# 4             5년 2,200만원         NaN    110만원   2,310만원       0원
# 5                 합계 1억원         NaN  1,550만원  11,550만원        -
# 6   - 만기 일시상환 방식을 선택한 경우         NaN      NaN       NaN      NaN
# 7                상환기간 원금         NaN       이자      상환금액     대출잔액
# 8                  1년 0원         NaN    500만원     500만원      1억원
# 9                  2년 0원         NaN    500만원     500만원      1억원
# 10                 3년 0원         NaN    500만원     500만원      1억원
# 11                 4년 0원         NaN    500만원     500만원      1억원
# 12                5년 1억원         NaN    500만원  10,500만원       0원
# ...

# %%
from DocLoader import dirloader
texts = dirloader('./financial_vocab')
texts
# Out:
# [Document(metadata={'source': './financial_vocab.txt'}, page_content='P2P금융\n- P2P는 Peer to Peer의 줄임말\n\n 온라인플랫폼을 통하여 투자자의 자금을 투자자가 지정한 차입자에게 대출하고 그 연계대출에 따른 원리금수취권을 투자자에게 제공하는 것을 말한다\n\n\n- 한국P2P금융협회에선 "온라인을 통해 대출-투자를 연결하는 핀테크 서비스"라고 정의하고 있다\n\n\n- P2P금융은 크라우드 펀딩에 속하는 펀딩(후원)형, 투자(증권)형, 대출형, 기부형 중 정해진 기간에 맞춰 원금과 약정 이자를 받는 대출형 크라우드 펀딩으로 분류할 수 있다\n\n대출계약 철회권\n- 일반금융소비자는 계약체결일, 계약서류를 받은 날, 대출금 수령일 중 가장 늦은 날로부터 14일(기간의 말일이 휴일인 경우 다음 영업일) 내에 계약을 철회할 수 있습니다\n\n\n(다만, 철회권을 행사하여 효력이 발생한 이후에는 이를 취소할 수 없습니다)\n- 대출 계약철회를 위해서는 은행에 대출계약 철회의 의사표시를 해야 하며, 이미 수령한 대출금과 이에 대한 이자, 대출과 관련하여 은행이 제3자에게 부담한 인지세, 근저당권설정비용 등을 반환하여야 합니다\n\n\n- 대출계약 철회권을 행사한 경우에는 중도해약금이 면제되며, 5영업일 이내에 해당 대출과 관련한 대출정보가 삭제됩니다\n\n중도상환해약금\n- 대출의 상환기일이 도래하기 전에 대출금을 상환할 경우 고객이 부담하는 금액\n- 다만, 기존 대출 계약을 해지하고 동일 은행과 사실상 동일한 계약(기존 계약에 따라 지급된 금전 등을 상환받는 새로운 계약)을 체결한 경우, 양 계약의 유지기간을 합하여 3년이 경과한 후 해지할 경우에는 중도상환해약금이 면제됩니다\n\n인지세\n- 인지세법에 의해 대출약정 체결 시 납부하는 세금\n\n\n- 대출금액에 따라 세액이 차등적용되며, 각 50%씩 고객과 은행이 부담합니다\n\n금리인하요구권\n- 금융소비자가 본인의 신용상태가 개선되
# ...
